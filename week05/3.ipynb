# %% [markdown]
# ![qq_pic_merged_1697542042525.jpg](attachment:qq_pic_merged_1697542042525.jpg)

# %%
def insertionSort(arr): 
    for i in range(1, len(arr)): 
        key = arr[i] 
        j = i-1
        while j >=0 and key < arr[j] : 
                arr[j+1] = arr[j] 
                j -= 1
        arr[j+1] = key 

a = list(map(int,input().split()))
insertionSort(a) 
print ("排序后的数组:") 
for i in range(len(a)): 
    print ("%d" %a[i])
# Out:
# 2 9 3 4 7 6
# 排序后的数组:
# 2
# 3
# 4
# 6
# 7
# 9
